# %% [markdown]
# # Otimização com Gradiente Descendente
#
# Utilizaremos o **Gradiente Descendente** para encontrar os parâmetros ideais (`intercept` e `slope`) da nossa Reta de Regressão:
#
# $$
# y_i = \beta_0 + \beta_1 x_i + \epsilon_i
# $$
#
# **Onde:**
# * **$y_i$**: Variável dependente (resposta) para a observação $i$.
# * **$x_i$**: Variável independente (explicativa) para a observação $i$.
# * **$\beta_0$**: **Intercept** (parâmetro que vamos otimizar).
# * **$\beta_1$**: **slope** (parâmetro que vamos otimizar).
# * **$\epsilon_i$**: **Erro aleatório**, a diferença entre o modelo e a realidade.
#
# O objetivo é ajustar $\beta_0$ e $\beta_1$ simultaneamente para minimizar o erro entre as previsões da reta e os dados reais (`x_data`, `y_data`).

# %% [markdown]
# ##Bibliotecas que usaremos

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %% [markdown]
# ## Definição das variaveis com os dados que usaremos:

# %%
import numpy as np
intercept = 0
slope = 1
x_data = np.array([0.5, 2.3, 2.9])
y_data = np.array([1.4, 1.9, 3.2])
max_iterations = 1000
precision = 0.0001
learning_rate = 0.01
list_intercepts = []
list_slopes = []
list_sum_of_squared_residuals = []

# %% [markdown]
# ##definição de funcões
# Para facilitar a leitura, vamos associar as variáveis do código aos símbolos matemáticos:
#
# > Adicionar aspas
#
#
#
# * **$b$**: `current_intercept`
# * **$m$**: `current_slop`
# * **$x_i$**: `x_data`
# * **$y_i$**: `y_data`

# %% [markdown]
# ### 1. Derivada em relação ao Intercepto ($b$)
# Correspondente à função `calculate_derivative_intercept`. Esta equação nos diz como o erro muda se ajustarmos apenas a altura da linha.
#
# $$
# \frac{\partial SSR}{\partial b} = \sum_{i=1}^{n} -2 (y_i - (b + m x_i))
# $$

# %%
def calculate_derivative_intercept(current_intercept, current_slop):
    predictions = current_intercept + current_slop * x_data
    residuals = y_data - predictions
    return np.sum(-2 * residuals)

# %% [markdown]
# ### 2. Derivada em relação à Inclinação ($m$)
# Correspondente à função `calculate_derivative_slop`. Esta equação nos diz como o erro muda se ajustarmos a angulação da linha. Note que aqui multiplicamos por $x_i$ no final (Regra da Cadeia).
#
# $$
# \frac{\partial SSR}{\partial m} = \sum_{i=1}^{n} -2 (y_i - (b + m x_i)) \cdot x_i
# $$

# %%
def calculate_derivative_slop(current_intercept, current_slop):
    predictions = current_intercept + current_slop * x_data
    residuals = y_data - predictions
    return np.sum(-2 * residuals * x_data)

# %% [markdown]
# ### Executando o Gradiente Descendente (Otimização de Intercepto e Slope)
#
# A cada iteração (passo do loop), o código realiza três tarefas principais, utilizando **todo o conjunto de dados**:
#
# 1.  **Calcula os Gradientes:** Determina a direção do erro para ambos os parâmetros com base em **todos os pontos** de dados simultaneamente.
# 2.  **Atualiza Intercepto e Slope:** Ajusta tanto a altura quanto a inclinação da reta para minimizar o erro.
# 3.  **Verifica a Precisão:** Se os passos de atualização para o intercepto e a inclinação forem pequenos demais (menores que a precisão definida), o loop encerra.
#
# O processo se repete até que o gradiente seja próximo de zero (convergência) ou o maximo de iterações for atingido.
#
# Também armazenamos o histórico dos valores de intercepto e inclinação para a visualização da convergência do algoritmo no gráfico posterior.

# %%
for i in range(max_iterations):
    list_intercepts.append(intercept)
    list_slopes.append(slope)

    derivative_intercept = calculate_derivative_intercept(intercept, slope)
    derivative_slope = calculate_derivative_slop(intercept, slope)

    intercept_step_size = learning_rate * derivative_intercept
    slope_step_size = learning_rate * derivative_slope

    print(f"""Step: {i+1},
              Step Size Intercept: {intercept_step_size:.4f},
              Step Size Slope: {slope_step_size:.4f},
              Old intercept: {intercept:.4f},
              Old slope: {slope:.4f},
              New intercept: {(intercept - intercept_step_size):.4f},
              New slope: {(slope - slope_step_size):.4f}""",
              flush=True)

    intercept = intercept - intercept_step_size
    slope = slope - slope_step_size

    if np.abs(intercept_step_size) < precision and np.abs(slope_step_size) < precision:
        break

print(f"\n--- Treinamento Concluído ---")
print(f"Intercept Final: {intercept:.4f}")
print(f"Slope Final: {slope:.4f}")
print(f"Total de Iterações: {len(list_intercepts)}")
# Out:
# Step: 1,
#               Step Size Intercept: -0.0160,
#               Step Size Slope: -0.0080,
#               Old intercept: 0.0000,
#               Old slope: 1.0000,
#               New intercept: 0.0160,
#               New slope: 1.0080
# Step: 2,
#               Step Size Intercept: -0.0141,
#               Step Size Slope: -0.0039,
#               Old intercept: 0.0160,
#               Old slope: 1.0080,
#               New intercept: 0.0301,
#               New slope: 1.0119
# Step: 3,
#               Step Size Intercept: -0.0128,
#               Step Size Slope: -0.0012,
#               Old intercept: 0.0301,
#               Old slope: 1.0119,
#               New intercept: 0.0430,
#               New slope: 1.0132
# Step: 4,
#               Step Size Intercept: -0.0119,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.0430,
#               Old slope: 1.0132,
#               New intercept: 0.0549,
#               New slope: 1.0126
# Step: 5,
#               Step Size Intercept: -0.0113,
#               Step Size Slope: 0.0018,
#               Old intercept: 0.0549,
#               Old slope: 1.0126,
#               New intercept: 0.0661,
#               New slope: 1.0108
# Step: 6,
#               Step Size Intercept: -0.0108,
#               Step Size Slope: 0.0026,
#               Old intercept: 0.0661,
#               Old slope: 1.0108,
#               New intercept: 0.0769,
#               New slope: 1.0083
# Step: 7,
#               Step Size Intercept: -0.0104,
#               Step Size Slope: 0.0031,
#               Old intercept: 0.0769,
#               Old slope: 1.0083,
#               New intercept: 0.0874,
#               New slope: 1.0052
# Step: 8,
#               Step Size Intercept: -0.0102,
#               Step Size Slope: 0.0034,
#               Old intercept: 0.0874,
#               Old slope: 1.0052,
#               New intercept: 0.0976,
#               New slope: 1.0018
# Step: 9,
#               Step Size Intercept: -0.0099,
#               Step Size Slope: 0.0036,
#               Old intercept: 0.0976,
#               Old slope: 1.0018,
#               New intercept: 0.1075,
#               New slope: 0.9982
# Step: 10,
#               Step Size Intercept: -0.0098,
#               Step Size Slope: 0.0037,
#               Old intercept: 0.1075,
#               Old slope: 0.9982,
#               New intercept: 0.1173,
#               New slope: 0.9944
# Step: 11,
#               Step Size Intercept: -0.0096,
#               Step Size Slope: 0.0038,
#               Old intercept: 0.1173,
#               Old slope: 0.9944,
#               New intercept: 0.1269,
#               New slope: 0.9906
# Step: 12,
#               Step Size Intercept: -0.0095,
#               Step Size Slope: 0.0038,
#               Old intercept: 0.1269,
#               Old slope: 0.9906,
#               New intercept: 0.1363,
#               New slope: 0.9868
# Step: 13,
#               Step Size Intercept: -0.0093,
#               Step Size Slope: 0.0038,
#               Old intercept: 0.1363,
#               Old slope: 0.9868,
#               New intercept: 0.1456,
#               New slope: 0.9829
# Step: 14,
#               Step Size Intercept: -0.0092,
#               Step Size Slope: 0.0038,
#               Old intercept: 0.1456,
#               Old slope: 0.9829,
#               New intercept: 0.1549,
#               New slope: 0.9791
# Step: 15,
#               Step Size Intercept: -0.0091,
#               Step Size Slope: 0.0038,
#               Old intercept: 0.1549,
#               Old slope: 0.9791,
#               New intercept: 0.1639,
#               New slope: 0.9753
# Step: 16,
#               Step Size Intercept: -0.0090,
#               Step Size Slope: 0.0038,
#               Old intercept: 0.1639,
#               Old slope: 0.9753,
#               New intercept: 0.1729,
#               New slope: 0.9715
# Step: 17,
#               Step Size Intercept: -0.0089,
#               Step Size Slope: 0.0038,
#               Old intercept: 0.1729,
#               Old slope: 0.9715,
#               New intercept: 0.1818,
#               New slope: 0.9677
# Step: 18,
#               Step Size Intercept: -0.0088,
#               Step Size Slope: 0.0037,
#               Old intercept: 0.1818,
#               Old slope: 0.9677,
#               New intercept: 0.1906,
#               New slope: 0.9640
# Step: 19,
#               Step Size Intercept: -0.0087,
#               Step Size Slope: 0.0037,
#               Old intercept: 0.1906,
#               Old slope: 0.9640,
#               New intercept: 0.1992,
#               New slope: 0.9603
# Step: 20,
#               Step Size Intercept: -0.0086,
#               Step Size Slope: 0.0036,
#               Old intercept: 0.1992,
#               Old slope: 0.9603,
#               New intercept: 0.2078,
#               New slope: 0.9567
# Step: 21,
#               Step Size Intercept: -0.0085,
#               Step Size Slope: 0.0036,
#               Old intercept: 0.2078,
#               Old slope: 0.9567,
#               New intercept: 0.2163,
#               New slope: 0.9531
# Step: 22,
#               Step Size Intercept: -0.0084,
#               Step Size Slope: 0.0036,
#               Old intercept: 0.2163,
#               Old slope: 0.9531,
#               New intercept: 0.2247,
#               New slope: 0.9495
# Step: 23,
#               Step Size Intercept: -0.0083,
#               Step Size Slope: 0.0035,
#               Old intercept: 0.2247,
#               Old slope: 0.9495,
#               New intercept: 0.2329,
#               New slope: 0.9460
# Step: 24,
#               Step Size Intercept: -0.0082,
#               Step Size Slope: 0.0035,
#               Old intercept: 0.2329,
#               Old slope: 0.9460,
#               New intercept: 0.2411,
#               New slope: 0.9425
# Step: 25,
#               Step Size Intercept: -0.0081,
#               Step Size Slope: 0.0034,
#               Old intercept: 0.2411,
#               Old slope: 0.9425,
#               New intercept: 0.2492,
#               New slope: 0.9391
# Step: 26,
#               Step Size Intercept: -0.0080,
#               Step Size Slope: 0.0034,
#               Old intercept: 0.2492,
#               Old slope: 0.9391,
#               New intercept: 0.2572,
#               New slope: 0.9356
# Step: 27,
#               Step Size Intercept: -0.0079,
#               Step Size Slope: 0.0034,
#               Old intercept: 0.2572,
#               Old slope: 0.9356,
#               New intercept: 0.2651,
#               New slope: 0.9323
# Step: 28,
#               Step Size Intercept: -0.0078,
#               Step Size Slope: 0.0033,
#               Old intercept: 0.2651,
#               Old slope: 0.9323,
#               New intercept: 0.2729,
#               New slope: 0.9290
# Step: 29,
#               Step Size Intercept: -0.0077,
#               Step Size Slope: 0.0033,
#               Old intercept: 0.2729,
#               Old slope: 0.9290,
#               New intercept: 0.2806,
#               New slope: 0.9257
# Step: 30,
#               Step Size Intercept: -0.0076,
#               Step Size Slope: 0.0033,
#               Old intercept: 0.2806,
#               Old slope: 0.9257,
#               New intercept: 0.2883,
#               New slope: 0.9224
# Step: 31,
#               Step Size Intercept: -0.0075,
#               Step Size Slope: 0.0032,
#               Old intercept: 0.2883,
#               Old slope: 0.9224,
#               New intercept: 0.2958,
#               New slope: 0.9192
# Step: 32,
#               Step Size Intercept: -0.0075,
#               Step Size Slope: 0.0032,
#               Old intercept: 0.2958,
#               Old slope: 0.9192,
#               New intercept: 0.3033,
#               New slope: 0.9160
# Step: 33,
#               Step Size Intercept: -0.0074,
#               Step Size Slope: 0.0031,
#               Old intercept: 0.3033,
#               Old slope: 0.9160,
#               New intercept: 0.3107,
#               New slope: 0.9129
# Step: 34,
#               Step Size Intercept: -0.0073,
#               Step Size Slope: 0.0031,
#               Old intercept: 0.3107,
#               Old slope: 0.9129,
#               New intercept: 0.3180,
#               New slope: 0.9098
# Step: 35,
#               Step Size Intercept: -0.0072,
#               Step Size Slope: 0.0031,
#               Old intercept: 0.3180,
#               Old slope: 0.9098,
#               New intercept: 0.3252,
#               New slope: 0.9067
# Step: 36,
#               Step Size Intercept: -0.0071,
#               Step Size Slope: 0.0030,
#               Old intercept: 0.3252,
#               Old slope: 0.9067,
#               New intercept: 0.3323,
#               New slope: 0.9037
# Step: 37,
#               Step Size Intercept: -0.0070,
#               Step Size Slope: 0.0030,
#               Old intercept: 0.3323,
#               Old slope: 0.9037,
#               New intercept: 0.3393,
#               New slope: 0.9007
# Step: 38,
#               Step Size Intercept: -0.0070,
#               Step Size Slope: 0.0030,
#               Old intercept: 0.3393,
#               Old slope: 0.9007,
#               New intercept: 0.3463,
#               New slope: 0.8977
# Step: 39,
#               Step Size Intercept: -0.0069,
#               Step Size Slope: 0.0029,
#               Old intercept: 0.3463,
#               Old slope: 0.8977,
#               New intercept: 0.3532,
#               New slope: 0.8948
# Step: 40,
#               Step Size Intercept: -0.0068,
#               Step Size Slope: 0.0029,
#               Old intercept: 0.3532,
#               Old slope: 0.8948,
#               New intercept: 0.3600,
#               New slope: 0.8919
# Step: 41,
#               Step Size Intercept: -0.0067,
#               Step Size Slope: 0.0029,
#               Old intercept: 0.3600,
#               Old slope: 0.8919,
#               New intercept: 0.3667,
#               New slope: 0.8890
# Step: 42,
#               Step Size Intercept: -0.0067,
#               Step Size Slope: 0.0028,
#               Old intercept: 0.3667,
#               Old slope: 0.8890,
#               New intercept: 0.3734,
#               New slope: 0.8862
# Step: 43,
#               Step Size Intercept: -0.0066,
#               Step Size Slope: 0.0028,
#               Old intercept: 0.3734,
#               Old slope: 0.8862,
#               New intercept: 0.3800,
#               New slope: 0.8834
# Step: 44,
#               Step Size Intercept: -0.0065,
#               Step Size Slope: 0.0028,
#               Old intercept: 0.3800,
#               Old slope: 0.8834,
#               New intercept: 0.3865,
#               New slope: 0.8806
# Step: 45,
#               Step Size Intercept: -0.0064,
#               Step Size Slope: 0.0027,
#               Old intercept: 0.3865,
#               Old slope: 0.8806,
#               New intercept: 0.3929,
#               New slope: 0.8778
# Step: 46,
#               Step Size Intercept: -0.0064,
#               Step Size Slope: 0.0027,
#               Old intercept: 0.3929,
#               Old slope: 0.8778,
#               New intercept: 0.3992,
#               New slope: 0.8751
# Step: 47,
#               Step Size Intercept: -0.0063,
#               Step Size Slope: 0.0027,
#               Old intercept: 0.3992,
#               Old slope: 0.8751,
#               New intercept: 0.4055,
#               New slope: 0.8725
# Step: 48,
#               Step Size Intercept: -0.0062,
#               Step Size Slope: 0.0026,
#               Old intercept: 0.4055,
#               Old slope: 0.8725,
#               New intercept: 0.4117,
#               New slope: 0.8698
# Step: 49,
#               Step Size Intercept: -0.0061,
#               Step Size Slope: 0.0026,
#               Old intercept: 0.4117,
#               Old slope: 0.8698,
#               New intercept: 0.4179,
#               New slope: 0.8672
# Step: 50,
#               Step Size Intercept: -0.0061,
#               Step Size Slope: 0.0026,
#               Old intercept: 0.4179,
#               Old slope: 0.8672,
#               New intercept: 0.4239,
#               New slope: 0.8646
# Step: 51,
#               Step Size Intercept: -0.0060,
#               Step Size Slope: 0.0026,
#               Old intercept: 0.4239,
#               Old slope: 0.8646,
#               New intercept: 0.4299,
#               New slope: 0.8621
# Step: 52,
#               Step Size Intercept: -0.0059,
#               Step Size Slope: 0.0025,
#               Old intercept: 0.4299,
#               Old slope: 0.8621,
#               New intercept: 0.4359,
#               New slope: 0.8595
# Step: 53,
#               Step Size Intercept: -0.0059,
#               Step Size Slope: 0.0025,
#               Old intercept: 0.4359,
#               Old slope: 0.8595,
#               New intercept: 0.4417,
#               New slope: 0.8570
# Step: 54,
#               Step Size Intercept: -0.0058,
#               Step Size Slope: 0.0025,
#               Old intercept: 0.4417,
#               Old slope: 0.8570,
#               New intercept: 0.4475,
#               New slope: 0.8546
# Step: 55,
#               Step Size Intercept: -0.0057,
#               Step Size Slope: 0.0024,
#               Old intercept: 0.4475,
#               Old slope: 0.8546,
#               New intercept: 0.4532,
#               New slope: 0.8521
# Step: 56,
#               Step Size Intercept: -0.0057,
#               Step Size Slope: 0.0024,
#               Old intercept: 0.4532,
#               Old slope: 0.8521,
#               New intercept: 0.4589,
#               New slope: 0.8497
# Step: 57,
#               Step Size Intercept: -0.0056,
#               Step Size Slope: 0.0024,
#               Old intercept: 0.4589,
#               Old slope: 0.8497,
#               New intercept: 0.4645,
#               New slope: 0.8473
# Step: 58,
#               Step Size Intercept: -0.0055,
#               Step Size Slope: 0.0024,
#               Old intercept: 0.4645,
#               Old slope: 0.8473,
#               New intercept: 0.4700,
#               New slope: 0.8450
# Step: 59,
#               Step Size Intercept: -0.0055,
#               Step Size Slope: 0.0023,
#               Old intercept: 0.4700,
#               Old slope: 0.8450,
#               New intercept: 0.4755,
#               New slope: 0.8426
# Step: 60,
#               Step Size Intercept: -0.0054,
#               Step Size Slope: 0.0023,
#               Old intercept: 0.4755,
#               Old slope: 0.8426,
#               New intercept: 0.4809,
#               New slope: 0.8403
# Step: 61,
#               Step Size Intercept: -0.0053,
#               Step Size Slope: 0.0023,
#               Old intercept: 0.4809,
#               Old slope: 0.8403,
#               New intercept: 0.4863,
#               New slope: 0.8381
# Step: 62,
#               Step Size Intercept: -0.0053,
#               Step Size Slope: 0.0023,
#               Old intercept: 0.4863,
#               Old slope: 0.8381,
#               New intercept: 0.4915,
#               New slope: 0.8358
# Step: 63,
#               Step Size Intercept: -0.0052,
#               Step Size Slope: 0.0022,
#               Old intercept: 0.4915,
#               Old slope: 0.8358,
#               New intercept: 0.4968,
#               New slope: 0.8336
# Step: 64,
#               Step Size Intercept: -0.0052,
#               Step Size Slope: 0.0022,
#               Old intercept: 0.4968,
#               Old slope: 0.8336,
#               New intercept: 0.5019,
#               New slope: 0.8314
# Step: 65,
#               Step Size Intercept: -0.0051,
#               Step Size Slope: 0.0022,
#               Old intercept: 0.5019,
#               Old slope: 0.8314,
#               New intercept: 0.5070,
#               New slope: 0.8292
# Step: 66,
#               Step Size Intercept: -0.0050,
#               Step Size Slope: 0.0022,
#               Old intercept: 0.5070,
#               Old slope: 0.8292,
#               New intercept: 0.5121,
#               New slope: 0.8271
# Step: 67,
#               Step Size Intercept: -0.0050,
#               Step Size Slope: 0.0021,
#               Old intercept: 0.5121,
#               Old slope: 0.8271,
#               New intercept: 0.5171,
#               New slope: 0.8249
# Step: 68,
#               Step Size Intercept: -0.0049,
#               Step Size Slope: 0.0021,
#               Old intercept: 0.5171,
#               Old slope: 0.8249,
#               New intercept: 0.5220,
#               New slope: 0.8228
# Step: 69,
#               Step Size Intercept: -0.0049,
#               Step Size Slope: 0.0021,
#               Old intercept: 0.5220,
#               Old slope: 0.8228,
#               New intercept: 0.5269,
#               New slope: 0.8207
# Step: 70,
#               Step Size Intercept: -0.0048,
#               Step Size Slope: 0.0021,
#               Old intercept: 0.5269,
#               Old slope: 0.8207,
#               New intercept: 0.5317,
#               New slope: 0.8187
# Step: 71,
#               Step Size Intercept: -0.0048,
#               Step Size Slope: 0.0020,
#               Old intercept: 0.5317,
#               Old slope: 0.8187,
#               New intercept: 0.5365,
#               New slope: 0.8167
# Step: 72,
#               Step Size Intercept: -0.0047,
#               Step Size Slope: 0.0020,
#               Old intercept: 0.5365,
#               Old slope: 0.8167,
#               New intercept: 0.5412,
#               New slope: 0.8147
# Step: 73,
#               Step Size Intercept: -0.0047,
#               Step Size Slope: 0.0020,
#               Old intercept: 0.5412,
#               Old slope: 0.8147,
#               New intercept: 0.5459,
#               New slope: 0.8127
# Step: 74,
#               Step Size Intercept: -0.0046,
#               Step Size Slope: 0.0020,
#               Old intercept: 0.5459,
#               Old slope: 0.8127,
#               New intercept: 0.5505,
#               New slope: 0.8107
# Step: 75,
#               Step Size Intercept: -0.0046,
#               Step Size Slope: 0.0019,
#               Old intercept: 0.5505,
#               Old slope: 0.8107,
#               New intercept: 0.5550,
#               New slope: 0.8088
# Step: 76,
#               Step Size Intercept: -0.0045,
#               Step Size Slope: 0.0019,
#               Old intercept: 0.5550,
#               Old slope: 0.8088,
#               New intercept: 0.5595,
#               New slope: 0.8069
# Step: 77,
#               Step Size Intercept: -0.0044,
#               Step Size Slope: 0.0019,
#               Old intercept: 0.5595,
#               Old slope: 0.8069,
#               New intercept: 0.5640,
#               New slope: 0.8050
# Step: 78,
#               Step Size Intercept: -0.0044,
#               Step Size Slope: 0.0019,
#               Old intercept: 0.5640,
#               Old slope: 0.8050,
#               New intercept: 0.5684,
#               New slope: 0.8031
# Step: 79,
#               Step Size Intercept: -0.0043,
#               Step Size Slope: 0.0019,
#               Old intercept: 0.5684,
#               Old slope: 0.8031,
#               New intercept: 0.5727,
#               New slope: 0.8012
# Step: 80,
#               Step Size Intercept: -0.0043,
#               Step Size Slope: 0.0018,
#               Old intercept: 0.5727,
#               Old slope: 0.8012,
#               New intercept: 0.5770,
#               New slope: 0.7994
# Step: 81,
#               Step Size Intercept: -0.0042,
#               Step Size Slope: 0.0018,
#               Old intercept: 0.5770,
#               Old slope: 0.7994,
#               New intercept: 0.5812,
#               New slope: 0.7976
# Step: 82,
#               Step Size Intercept: -0.0042,
#               Step Size Slope: 0.0018,
#               Old intercept: 0.5812,
#               Old slope: 0.7976,
#               New intercept: 0.5854,
#               New slope: 0.7958
# Step: 83,
#               Step Size Intercept: -0.0042,
#               Step Size Slope: 0.0018,
#               Old intercept: 0.5854,
#               Old slope: 0.7958,
#               New intercept: 0.5896,
#               New slope: 0.7940
# Step: 84,
#               Step Size Intercept: -0.0041,
#               Step Size Slope: 0.0017,
#               Old intercept: 0.5896,
#               Old slope: 0.7940,
#               New intercept: 0.5937,
#               New slope: 0.7923
# Step: 85,
#               Step Size Intercept: -0.0041,
#               Step Size Slope: 0.0017,
#               Old intercept: 0.5937,
#               Old slope: 0.7923,
#               New intercept: 0.5978,
#               New slope: 0.7906
# Step: 86,
#               Step Size Intercept: -0.0040,
#               Step Size Slope: 0.0017,
#               Old intercept: 0.5978,
#               Old slope: 0.7906,
#               New intercept: 0.6018,
#               New slope: 0.7888
# Step: 87,
#               Step Size Intercept: -0.0040,
#               Step Size Slope: 0.0017,
#               Old intercept: 0.6018,
#               Old slope: 0.7888,
#               New intercept: 0.6057,
#               New slope: 0.7872
# Step: 88,
#               Step Size Intercept: -0.0039,
#               Step Size Slope: 0.0017,
#               Old intercept: 0.6057,
#               Old slope: 0.7872,
#               New intercept: 0.6097,
#               New slope: 0.7855
# Step: 89,
#               Step Size Intercept: -0.0039,
#               Step Size Slope: 0.0017,
#               Old intercept: 0.6097,
#               Old slope: 0.7855,
#               New intercept: 0.6135,
#               New slope: 0.7838
# Step: 90,
#               Step Size Intercept: -0.0038,
#               Step Size Slope: 0.0016,
#               Old intercept: 0.6135,
#               Old slope: 0.7838,
#               New intercept: 0.6174,
#               New slope: 0.7822
# Step: 91,
#               Step Size Intercept: -0.0038,
#               Step Size Slope: 0.0016,
#               Old intercept: 0.6174,
#               Old slope: 0.7822,
#               New intercept: 0.6212,
#               New slope: 0.7806
# Step: 92,
#               Step Size Intercept: -0.0037,
#               Step Size Slope: 0.0016,
#               Old intercept: 0.6212,
#               Old slope: 0.7806,
#               New intercept: 0.6249,
#               New slope: 0.7790
# Step: 93,
#               Step Size Intercept: -0.0037,
#               Step Size Slope: 0.0016,
#               Old intercept: 0.6249,
#               Old slope: 0.7790,
#               New intercept: 0.6286,
#               New slope: 0.7774
# Step: 94,
#               Step Size Intercept: -0.0037,
#               Step Size Slope: 0.0016,
#               Old intercept: 0.6286,
#               Old slope: 0.7774,
#               New intercept: 0.6323,
#               New slope: 0.7759
# Step: 95,
#               Step Size Intercept: -0.0036,
#               Step Size Slope: 0.0015,
#               Old intercept: 0.6323,
#               Old slope: 0.7759,
#               New intercept: 0.6359,
#               New slope: 0.7743
# Step: 96,
#               Step Size Intercept: -0.0036,
#               Step Size Slope: 0.0015,
#               Old intercept: 0.6359,
#               Old slope: 0.7743,
#               New intercept: 0.6394,
#               New slope: 0.7728
# Step: 97,
#               Step Size Intercept: -0.0035,
#               Step Size Slope: 0.0015,
#               Old intercept: 0.6394,
#               Old slope: 0.7728,
#               New intercept: 0.6430,
#               New slope: 0.7713
# Step: 98,
#               Step Size Intercept: -0.0035,
#               Step Size Slope: 0.0015,
#               Old intercept: 0.6430,
#               Old slope: 0.7713,
#               New intercept: 0.6465,
#               New slope: 0.7698
# Step: 99,
#               Step Size Intercept: -0.0035,
#               Step Size Slope: 0.0015,
#               Old intercept: 0.6465,
#               Old slope: 0.7698,
#               New intercept: 0.6499,
#               New slope: 0.7683
# Step: 100,
#               Step Size Intercept: -0.0034,
#               Step Size Slope: 0.0015,
#               Old intercept: 0.6499,
#               Old slope: 0.7683,
#               New intercept: 0.6533,
#               New slope: 0.7669
# Step: 101,
#               Step Size Intercept: -0.0034,
#               Step Size Slope: 0.0014,
#               Old intercept: 0.6533,
#               Old slope: 0.7669,
#               New intercept: 0.6567,
#               New slope: 0.7654
# Step: 102,
#               Step Size Intercept: -0.0033,
#               Step Size Slope: 0.0014,
#               Old intercept: 0.6567,
#               Old slope: 0.7654,
#               New intercept: 0.6601,
#               New slope: 0.7640
# Step: 103,
#               Step Size Intercept: -0.0033,
#               Step Size Slope: 0.0014,
#               Old intercept: 0.6601,
#               Old slope: 0.7640,
#               New intercept: 0.6634,
#               New slope: 0.7626
# Step: 104,
#               Step Size Intercept: -0.0033,
#               Step Size Slope: 0.0014,
#               Old intercept: 0.6634,
#               Old slope: 0.7626,
#               New intercept: 0.6666,
#               New slope: 0.7612
# Step: 105,
#               Step Size Intercept: -0.0032,
#               Step Size Slope: 0.0014,
#               Old intercept: 0.6666,
#               Old slope: 0.7612,
#               New intercept: 0.6698,
#               New slope: 0.7598
# Step: 106,
#               Step Size Intercept: -0.0032,
#               Step Size Slope: 0.0014,
#               Old intercept: 0.6698,
#               Old slope: 0.7598,
#               New intercept: 0.6730,
#               New slope: 0.7585
# Step: 107,
#               Step Size Intercept: -0.0032,
#               Step Size Slope: 0.0013,
#               Old intercept: 0.6730,
#               Old slope: 0.7585,
#               New intercept: 0.6762,
#               New slope: 0.7571
# Step: 108,
#               Step Size Intercept: -0.0031,
#               Step Size Slope: 0.0013,
#               Old intercept: 0.6762,
#               Old slope: 0.7571,
#               New intercept: 0.6793,
#               New slope: 0.7558
# Step: 109,
#               Step Size Intercept: -0.0031,
#               Step Size Slope: 0.0013,
#               Old intercept: 0.6793,
#               Old slope: 0.7558,
#               New intercept: 0.6824,
#               New slope: 0.7545
# Step: 110,
#               Step Size Intercept: -0.0030,
#               Step Size Slope: 0.0013,
#               Old intercept: 0.6824,
#               Old slope: 0.7545,
#               New intercept: 0.6854,
#               New slope: 0.7532
# Step: 111,
#               Step Size Intercept: -0.0030,
#               Step Size Slope: 0.0013,
#               Old intercept: 0.6854,
#               Old slope: 0.7532,
#               New intercept: 0.6884,
#               New slope: 0.7519
# Step: 112,
#               Step Size Intercept: -0.0030,
#               Step Size Slope: 0.0013,
#               Old intercept: 0.6884,
#               Old slope: 0.7519,
#               New intercept: 0.6914,
#               New slope: 0.7507
# Step: 113,
#               Step Size Intercept: -0.0029,
#               Step Size Slope: 0.0013,
#               Old intercept: 0.6914,
#               Old slope: 0.7507,
#               New intercept: 0.6943,
#               New slope: 0.7494
# Step: 114,
#               Step Size Intercept: -0.0029,
#               Step Size Slope: 0.0012,
#               Old intercept: 0.6943,
#               Old slope: 0.7494,
#               New intercept: 0.6973,
#               New slope: 0.7482
# Step: 115,
#               Step Size Intercept: -0.0029,
#               Step Size Slope: 0.0012,
#               Old intercept: 0.6973,
#               Old slope: 0.7482,
#               New intercept: 0.7001,
#               New slope: 0.7469
# Step: 116,
#               Step Size Intercept: -0.0028,
#               Step Size Slope: 0.0012,
#               Old intercept: 0.7001,
#               Old slope: 0.7469,
#               New intercept: 0.7030,
#               New slope: 0.7457
# Step: 117,
#               Step Size Intercept: -0.0028,
#               Step Size Slope: 0.0012,
#               Old intercept: 0.7030,
#               Old slope: 0.7457,
#               New intercept: 0.7058,
#               New slope: 0.7445
# Step: 118,
#               Step Size Intercept: -0.0028,
#               Step Size Slope: 0.0012,
#               Old intercept: 0.7058,
#               Old slope: 0.7445,
#               New intercept: 0.7086,
#               New slope: 0.7433
# Step: 119,
#               Step Size Intercept: -0.0027,
#               Step Size Slope: 0.0012,
#               Old intercept: 0.7086,
#               Old slope: 0.7433,
#               New intercept: 0.7113,
#               New slope: 0.7422
# Step: 120,
#               Step Size Intercept: -0.0027,
#               Step Size Slope: 0.0012,
#               Old intercept: 0.7113,
#               Old slope: 0.7422,
#               New intercept: 0.7140,
#               New slope: 0.7410
# Step: 121,
#               Step Size Intercept: -0.0027,
#               Step Size Slope: 0.0011,
#               Old intercept: 0.7140,
#               Old slope: 0.7410,
#               New intercept: 0.7167,
#               New slope: 0.7399
# Step: 122,
#               Step Size Intercept: -0.0027,
#               Step Size Slope: 0.0011,
#               Old intercept: 0.7167,
#               Old slope: 0.7399,
#               New intercept: 0.7193,
#               New slope: 0.7387
# Step: 123,
#               Step Size Intercept: -0.0026,
#               Step Size Slope: 0.0011,
#               Old intercept: 0.7193,
#               Old slope: 0.7387,
#               New intercept: 0.7220,
#               New slope: 0.7376
# Step: 124,
#               Step Size Intercept: -0.0026,
#               Step Size Slope: 0.0011,
#               Old intercept: 0.7220,
#               Old slope: 0.7376,
#               New intercept: 0.7246,
#               New slope: 0.7365
# Step: 125,
#               Step Size Intercept: -0.0026,
#               Step Size Slope: 0.0011,
#               Old intercept: 0.7246,
#               Old slope: 0.7365,
#               New intercept: 0.7271,
#               New slope: 0.7354
# Step: 126,
#               Step Size Intercept: -0.0025,
#               Step Size Slope: 0.0011,
#               Old intercept: 0.7271,
#               Old slope: 0.7354,
#               New intercept: 0.7297,
#               New slope: 0.7344
# Step: 127,
#               Step Size Intercept: -0.0025,
#               Step Size Slope: 0.0011,
#               Old intercept: 0.7297,
#               Old slope: 0.7344,
#               New intercept: 0.7322,
#               New slope: 0.7333
# Step: 128,
#               Step Size Intercept: -0.0025,
#               Step Size Slope: 0.0011,
#               Old intercept: 0.7322,
#               Old slope: 0.7333,
#               New intercept: 0.7346,
#               New slope: 0.7322
# Step: 129,
#               Step Size Intercept: -0.0024,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7346,
#               Old slope: 0.7322,
#               New intercept: 0.7371,
#               New slope: 0.7312
# Step: 130,
#               Step Size Intercept: -0.0024,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7371,
#               Old slope: 0.7312,
#               New intercept: 0.7395,
#               New slope: 0.7302
# Step: 131,
#               Step Size Intercept: -0.0024,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7395,
#               Old slope: 0.7302,
#               New intercept: 0.7419,
#               New slope: 0.7291
# Step: 132,
#               Step Size Intercept: -0.0024,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7419,
#               Old slope: 0.7291,
#               New intercept: 0.7443,
#               New slope: 0.7281
# Step: 133,
#               Step Size Intercept: -0.0023,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7443,
#               Old slope: 0.7281,
#               New intercept: 0.7466,
#               New slope: 0.7271
# Step: 134,
#               Step Size Intercept: -0.0023,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7466,
#               Old slope: 0.7271,
#               New intercept: 0.7489,
#               New slope: 0.7262
# Step: 135,
#               Step Size Intercept: -0.0023,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7489,
#               Old slope: 0.7262,
#               New intercept: 0.7512,
#               New slope: 0.7252
# Step: 136,
#               Step Size Intercept: -0.0023,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7512,
#               Old slope: 0.7252,
#               New intercept: 0.7534,
#               New slope: 0.7242
# Step: 137,
#               Step Size Intercept: -0.0022,
#               Step Size Slope: 0.0010,
#               Old intercept: 0.7534,
#               Old slope: 0.7242,
#               New intercept: 0.7557,
#               New slope: 0.7233
# Step: 138,
#               Step Size Intercept: -0.0022,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7557,
#               Old slope: 0.7233,
#               New intercept: 0.7579,
#               New slope: 0.7223
# Step: 139,
#               Step Size Intercept: -0.0022,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7579,
#               Old slope: 0.7223,
#               New intercept: 0.7601,
#               New slope: 0.7214
# Step: 140,
#               Step Size Intercept: -0.0022,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7601,
#               Old slope: 0.7214,
#               New intercept: 0.7622,
#               New slope: 0.7205
# Step: 141,
#               Step Size Intercept: -0.0021,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7622,
#               Old slope: 0.7205,
#               New intercept: 0.7644,
#               New slope: 0.7196
# Step: 142,
#               Step Size Intercept: -0.0021,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7644,
#               Old slope: 0.7196,
#               New intercept: 0.7665,
#               New slope: 0.7187
# Step: 143,
#               Step Size Intercept: -0.0021,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7665,
#               Old slope: 0.7187,
#               New intercept: 0.7685,
#               New slope: 0.7178
# Step: 144,
#               Step Size Intercept: -0.0021,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7685,
#               Old slope: 0.7178,
#               New intercept: 0.7706,
#               New slope: 0.7169
# Step: 145,
#               Step Size Intercept: -0.0020,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7706,
#               Old slope: 0.7169,
#               New intercept: 0.7726,
#               New slope: 0.7160
# Step: 146,
#               Step Size Intercept: -0.0020,
#               Step Size Slope: 0.0009,
#               Old intercept: 0.7726,
#               Old slope: 0.7160,
#               New intercept: 0.7747,
#               New slope: 0.7152
# Step: 147,
#               Step Size Intercept: -0.0020,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7747,
#               Old slope: 0.7152,
#               New intercept: 0.7766,
#               New slope: 0.7143
# Step: 148,
#               Step Size Intercept: -0.0020,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7766,
#               Old slope: 0.7143,
#               New intercept: 0.7786,
#               New slope: 0.7135
# Step: 149,
#               Step Size Intercept: -0.0019,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7786,
#               Old slope: 0.7135,
#               New intercept: 0.7806,
#               New slope: 0.7127
# Step: 150,
#               Step Size Intercept: -0.0019,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7806,
#               Old slope: 0.7127,
#               New intercept: 0.7825,
#               New slope: 0.7119
# Step: 151,
#               Step Size Intercept: -0.0019,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7825,
#               Old slope: 0.7119,
#               New intercept: 0.7844,
#               New slope: 0.7110
# Step: 152,
#               Step Size Intercept: -0.0019,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7844,
#               Old slope: 0.7110,
#               New intercept: 0.7863,
#               New slope: 0.7102
# Step: 153,
#               Step Size Intercept: -0.0019,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7863,
#               Old slope: 0.7102,
#               New intercept: 0.7881,
#               New slope: 0.7095
# Step: 154,
#               Step Size Intercept: -0.0018,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7881,
#               Old slope: 0.7095,
#               New intercept: 0.7899,
#               New slope: 0.7087
# Step: 155,
#               Step Size Intercept: -0.0018,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7899,
#               Old slope: 0.7087,
#               New intercept: 0.7918,
#               New slope: 0.7079
# Step: 156,
#               Step Size Intercept: -0.0018,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7918,
#               Old slope: 0.7079,
#               New intercept: 0.7936,
#               New slope: 0.7071
# Step: 157,
#               Step Size Intercept: -0.0018,
#               Step Size Slope: 0.0008,
#               Old intercept: 0.7936,
#               Old slope: 0.7071,
#               New intercept: 0.7953,
#               New slope: 0.7064
# Step: 158,
#               Step Size Intercept: -0.0018,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.7953,
#               Old slope: 0.7064,
#               New intercept: 0.7971,
#               New slope: 0.7056
# Step: 159,
#               Step Size Intercept: -0.0017,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.7971,
#               Old slope: 0.7056,
#               New intercept: 0.7988,
#               New slope: 0.7049
# Step: 160,
#               Step Size Intercept: -0.0017,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.7988,
#               Old slope: 0.7049,
#               New intercept: 0.8005,
#               New slope: 0.7042
# Step: 161,
#               Step Size Intercept: -0.0017,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8005,
#               Old slope: 0.7042,
#               New intercept: 0.8022,
#               New slope: 0.7034
# Step: 162,
#               Step Size Intercept: -0.0017,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8022,
#               Old slope: 0.7034,
#               New intercept: 0.8039,
#               New slope: 0.7027
# Step: 163,
#               Step Size Intercept: -0.0017,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8039,
#               Old slope: 0.7027,
#               New intercept: 0.8056,
#               New slope: 0.7020
# Step: 164,
#               Step Size Intercept: -0.0016,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8056,
#               Old slope: 0.7020,
#               New intercept: 0.8072,
#               New slope: 0.7013
# Step: 165,
#               Step Size Intercept: -0.0016,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8072,
#               Old slope: 0.7013,
#               New intercept: 0.8088,
#               New slope: 0.7006
# Step: 166,
#               Step Size Intercept: -0.0016,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8088,
#               Old slope: 0.7006,
#               New intercept: 0.8104,
#               New slope: 0.7000
# Step: 167,
#               Step Size Intercept: -0.0016,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8104,
#               Old slope: 0.7000,
#               New intercept: 0.8120,
#               New slope: 0.6993
# Step: 168,
#               Step Size Intercept: -0.0016,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8120,
#               Old slope: 0.6993,
#               New intercept: 0.8135,
#               New slope: 0.6986
# Step: 169,
#               Step Size Intercept: -0.0015,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8135,
#               Old slope: 0.6986,
#               New intercept: 0.8151,
#               New slope: 0.6980
# Step: 170,
#               Step Size Intercept: -0.0015,
#               Step Size Slope: 0.0007,
#               Old intercept: 0.8151,
#               Old slope: 0.6980,
#               New intercept: 0.8166,
#               New slope: 0.6973
# Step: 171,
#               Step Size Intercept: -0.0015,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8166,
#               Old slope: 0.6973,
#               New intercept: 0.8181,
#               New slope: 0.6967
# Step: 172,
#               Step Size Intercept: -0.0015,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8181,
#               Old slope: 0.6967,
#               New intercept: 0.8196,
#               New slope: 0.6960
# Step: 173,
#               Step Size Intercept: -0.0015,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8196,
#               Old slope: 0.6960,
#               New intercept: 0.8211,
#               New slope: 0.6954
# Step: 174,
#               Step Size Intercept: -0.0015,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8211,
#               Old slope: 0.6954,
#               New intercept: 0.8226,
#               New slope: 0.6948
# Step: 175,
#               Step Size Intercept: -0.0014,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8226,
#               Old slope: 0.6948,
#               New intercept: 0.8240,
#               New slope: 0.6942
# Step: 176,
#               Step Size Intercept: -0.0014,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8240,
#               Old slope: 0.6942,
#               New intercept: 0.8254,
#               New slope: 0.6936
# Step: 177,
#               Step Size Intercept: -0.0014,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8254,
#               Old slope: 0.6936,
#               New intercept: 0.8268,
#               New slope: 0.6930
# Step: 178,
#               Step Size Intercept: -0.0014,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8268,
#               Old slope: 0.6930,
#               New intercept: 0.8282,
#               New slope: 0.6924
# Step: 179,
#               Step Size Intercept: -0.0014,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8282,
#               Old slope: 0.6924,
#               New intercept: 0.8296,
#               New slope: 0.6918
# Step: 180,
#               Step Size Intercept: -0.0014,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8296,
#               Old slope: 0.6918,
#               New intercept: 0.8310,
#               New slope: 0.6912
# Step: 181,
#               Step Size Intercept: -0.0013,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8310,
#               Old slope: 0.6912,
#               New intercept: 0.8323,
#               New slope: 0.6906
# Step: 182,
#               Step Size Intercept: -0.0013,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8323,
#               Old slope: 0.6906,
#               New intercept: 0.8336,
#               New slope: 0.6901
# Step: 183,
#               Step Size Intercept: -0.0013,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8336,
#               Old slope: 0.6901,
#               New intercept: 0.8350,
#               New slope: 0.6895
# Step: 184,
#               Step Size Intercept: -0.0013,
#               Step Size Slope: 0.0006,
#               Old intercept: 0.8350,
#               Old slope: 0.6895,
#               New intercept: 0.8363,
#               New slope: 0.6889
# Step: 185,
#               Step Size Intercept: -0.0013,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8363,
#               Old slope: 0.6889,
#               New intercept: 0.8375,
#               New slope: 0.6884
# Step: 186,
#               Step Size Intercept: -0.0013,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8375,
#               Old slope: 0.6884,
#               New intercept: 0.8388,
#               New slope: 0.6879
# Step: 187,
#               Step Size Intercept: -0.0013,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8388,
#               Old slope: 0.6879,
#               New intercept: 0.8401,
#               New slope: 0.6873
# Step: 188,
#               Step Size Intercept: -0.0012,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8401,
#               Old slope: 0.6873,
#               New intercept: 0.8413,
#               New slope: 0.6868
# Step: 189,
#               Step Size Intercept: -0.0012,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8413,
#               Old slope: 0.6868,
#               New intercept: 0.8425,
#               New slope: 0.6863
# Step: 190,
#               Step Size Intercept: -0.0012,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8425,
#               Old slope: 0.6863,
#               New intercept: 0.8438,
#               New slope: 0.6857
# Step: 191,
#               Step Size Intercept: -0.0012,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8438,
#               Old slope: 0.6857,
#               New intercept: 0.8450,
#               New slope: 0.6852
# Step: 192,
#               Step Size Intercept: -0.0012,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8450,
#               Old slope: 0.6852,
#               New intercept: 0.8461,
#               New slope: 0.6847
# Step: 193,
#               Step Size Intercept: -0.0012,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8461,
#               Old slope: 0.6847,
#               New intercept: 0.8473,
#               New slope: 0.6842
# Step: 194,
#               Step Size Intercept: -0.0012,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8473,
#               Old slope: 0.6842,
#               New intercept: 0.8485,
#               New slope: 0.6837
# Step: 195,
#               Step Size Intercept: -0.0011,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8485,
#               Old slope: 0.6837,
#               New intercept: 0.8496,
#               New slope: 0.6832
# Step: 196,
#               Step Size Intercept: -0.0011,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8496,
#               Old slope: 0.6832,
#               New intercept: 0.8507,
#               New slope: 0.6828
# Step: 197,
#               Step Size Intercept: -0.0011,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8507,
#               Old slope: 0.6828,
#               New intercept: 0.8519,
#               New slope: 0.6823
# Step: 198,
#               Step Size Intercept: -0.0011,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8519,
#               Old slope: 0.6823,
#               New intercept: 0.8530,
#               New slope: 0.6818
# Step: 199,
#               Step Size Intercept: -0.0011,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8530,
#               Old slope: 0.6818,
#               New intercept: 0.8541,
#               New slope: 0.6814
# Step: 200,
#               Step Size Intercept: -0.0011,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8541,
#               Old slope: 0.6814,
#               New intercept: 0.8552,
#               New slope: 0.6809
# Step: 201,
#               Step Size Intercept: -0.0011,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8552,
#               Old slope: 0.6809,
#               New intercept: 0.8562,
#               New slope: 0.6804
# Step: 202,
#               Step Size Intercept: -0.0011,
#               Step Size Slope: 0.0005,
#               Old intercept: 0.8562,
#               Old slope: 0.6804,
#               New intercept: 0.8573,
#               New slope: 0.6800
# Step: 203,
#               Step Size Intercept: -0.0010,
#               Step Size Slope: 0.0004,
#               Old intercept: 0.8573,
#               Old slope: 0.6800,
#               New intercept: 0.8583,
#               New slope: 0.6795
# Step: 204,
#               Step Size Intercept: -0.0010,
#               Step Size Slope: 0.0004,
#               Old intercept: 0.8583,
#               Old slope: 0.6795,
#               New intercept: 0.8594,
#               New slope: 0.6791
# Step: 205,
#               Step Size Intercept: -0.0010,
#               Step Size Slope: 0.0004,
#               Old intercept: 0.8594,
#               Old slope: 0.6791,
#               New intercept: 0.8604,
#               New slope: 0.6787
# Step: 206,
#               Step Size Intercept: -0.0010,
#               Step Size Slope: 0.0004,
#               Old intercept: 0.8604,
#               Old slope: 0.6787,
#               New intercept: 0.8614,
#               New slope: 0.6782
# Step: 207,
#               Step Size Intercept: -0.0010,
#               Step Size Slope: 0.0004,
# ...
#               New slope: 0.6490
# Step: 341,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9300,
#               Old slope: 0.6490,
#               New intercept: 0.9302,
#               New slope: 0.6489
# Step: 342,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9302,
#               Old slope: 0.6489,
#               New intercept: 0.9304,
#               New slope: 0.6488
# Step: 343,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9304,
#               Old slope: 0.6488,
#               New intercept: 0.9306,
#               New slope: 0.6487
# Step: 344,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9306,
#               Old slope: 0.6487,
#               New intercept: 0.9308,
#               New slope: 0.6486
# Step: 345,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9308,
#               Old slope: 0.6486,
#               New intercept: 0.9310,
#               New slope: 0.6486
# Step: 346,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9310,
#               Old slope: 0.6486,
#               New intercept: 0.9313,
#               New slope: 0.6485
# Step: 347,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9313,
#               Old slope: 0.6485,
#               New intercept: 0.9314,
#               New slope: 0.6484
# Step: 348,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9314,
#               Old slope: 0.6484,
#               New intercept: 0.9316,
#               New slope: 0.6483
# Step: 349,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9316,
#               Old slope: 0.6483,
#               New intercept: 0.9318,
#               New slope: 0.6482
# Step: 350,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9318,
#               Old slope: 0.6482,
#               New intercept: 0.9320,
#               New slope: 0.6481
# Step: 351,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9320,
#               Old slope: 0.6481,
#               New intercept: 0.9322,
#               New slope: 0.6481
# Step: 352,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9322,
#               Old slope: 0.6481,
#               New intercept: 0.9324,
#               New slope: 0.6480
# Step: 353,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9324,
#               Old slope: 0.6480,
#               New intercept: 0.9326,
#               New slope: 0.6479
# Step: 354,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9326,
#               Old slope: 0.6479,
#               New intercept: 0.9328,
#               New slope: 0.6478
# Step: 355,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9328,
#               Old slope: 0.6478,
#               New intercept: 0.9330,
#               New slope: 0.6477
# Step: 356,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9330,
#               Old slope: 0.6477,
#               New intercept: 0.9331,
#               New slope: 0.6477
# Step: 357,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9331,
#               Old slope: 0.6477,
#               New intercept: 0.9333,
#               New slope: 0.6476
# Step: 358,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9333,
#               Old slope: 0.6476,
#               New intercept: 0.9335,
#               New slope: 0.6475
# Step: 359,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9335,
#               Old slope: 0.6475,
#               New intercept: 0.9337,
#               New slope: 0.6474
# Step: 360,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9337,
#               Old slope: 0.6474,
#               New intercept: 0.9338,
#               New slope: 0.6474
# Step: 361,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9338,
#               Old slope: 0.6474,
#               New intercept: 0.9340,
#               New slope: 0.6473
# Step: 362,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9340,
#               Old slope: 0.6473,
#               New intercept: 0.9342,
#               New slope: 0.6472
# Step: 363,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9342,
#               Old slope: 0.6472,
#               New intercept: 0.9344,
#               New slope: 0.6471
# Step: 364,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9344,
#               Old slope: 0.6471,
#               New intercept: 0.9345,
#               New slope: 0.6471
# Step: 365,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9345,
#               Old slope: 0.6471,
#               New intercept: 0.9347,
#               New slope: 0.6470
# Step: 366,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9347,
#               Old slope: 0.6470,
#               New intercept: 0.9348,
#               New slope: 0.6469
# Step: 367,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9348,
#               Old slope: 0.6469,
#               New intercept: 0.9350,
#               New slope: 0.6469
# Step: 368,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9350,
#               Old slope: 0.6469,
#               New intercept: 0.9352,
#               New slope: 0.6468
# Step: 369,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9352,
#               Old slope: 0.6468,
#               New intercept: 0.9353,
#               New slope: 0.6467
# Step: 370,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9353,
#               Old slope: 0.6467,
#               New intercept: 0.9355,
#               New slope: 0.6467
# Step: 371,
#               Step Size Intercept: -0.0002,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9355,
#               Old slope: 0.6467,
#               New intercept: 0.9356,
#               New slope: 0.6466
# Step: 372,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9356,
#               Old slope: 0.6466,
#               New intercept: 0.9358,
#               New slope: 0.6465
# Step: 373,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9358,
#               Old slope: 0.6465,
#               New intercept: 0.9359,
#               New slope: 0.6465
# Step: 374,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9359,
#               Old slope: 0.6465,
#               New intercept: 0.9361,
#               New slope: 0.6464
# Step: 375,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9361,
#               Old slope: 0.6464,
#               New intercept: 0.9362,
#               New slope: 0.6464
# Step: 376,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9362,
#               Old slope: 0.6464,
#               New intercept: 0.9363,
#               New slope: 0.6463
# Step: 377,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9363,
#               Old slope: 0.6463,
#               New intercept: 0.9365,
#               New slope: 0.6462
# Step: 378,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9365,
#               Old slope: 0.6462,
#               New intercept: 0.9366,
#               New slope: 0.6462
# Step: 379,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9366,
#               Old slope: 0.6462,
#               New intercept: 0.9368,
#               New slope: 0.6461
# Step: 380,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9368,
#               Old slope: 0.6461,
#               New intercept: 0.9369,
#               New slope: 0.6461
# Step: 381,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9369,
#               Old slope: 0.6461,
#               New intercept: 0.9370,
#               New slope: 0.6460
# Step: 382,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9370,
#               Old slope: 0.6460,
#               New intercept: 0.9372,
#               New slope: 0.6459
# Step: 383,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9372,
#               Old slope: 0.6459,
#               New intercept: 0.9373,
#               New slope: 0.6459
# Step: 384,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9373,
#               Old slope: 0.6459,
#               New intercept: 0.9374,
#               New slope: 0.6458
# Step: 385,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9374,
#               Old slope: 0.6458,
#               New intercept: 0.9376,
#               New slope: 0.6458
# Step: 386,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9376,
#               Old slope: 0.6458,
#               New intercept: 0.9377,
#               New slope: 0.6457
# Step: 387,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9377,
#               Old slope: 0.6457,
#               New intercept: 0.9378,
#               New slope: 0.6457
# Step: 388,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9378,
#               Old slope: 0.6457,
#               New intercept: 0.9379,
#               New slope: 0.6456
# Step: 389,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9379,
#               Old slope: 0.6456,
#               New intercept: 0.9381,
#               New slope: 0.6456
# Step: 390,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9381,
#               Old slope: 0.6456,
#               New intercept: 0.9382,
#               New slope: 0.6455
# Step: 391,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9382,
#               Old slope: 0.6455,
#               New intercept: 0.9383,
#               New slope: 0.6455
# Step: 392,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9383,
#               Old slope: 0.6455,
#               New intercept: 0.9384,
#               New slope: 0.6454
# Step: 393,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0001,
#               Old intercept: 0.9384,
#               Old slope: 0.6454,
#               New intercept: 0.9385,
#               New slope: 0.6454
# Step: 394,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9385,
#               Old slope: 0.6454,
#               New intercept: 0.9387,
#               New slope: 0.6453
# Step: 395,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9387,
#               Old slope: 0.6453,
#               New intercept: 0.9388,
#               New slope: 0.6453
# Step: 396,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9388,
#               Old slope: 0.6453,
#               New intercept: 0.9389,
#               New slope: 0.6452
# Step: 397,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9389,
#               Old slope: 0.6452,
#               New intercept: 0.9390,
#               New slope: 0.6452
# Step: 398,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9390,
#               Old slope: 0.6452,
#               New intercept: 0.9391,
#               New slope: 0.6451
# Step: 399,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9391,
#               Old slope: 0.6451,
#               New intercept: 0.9392,
#               New slope: 0.6451
# Step: 400,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9392,
#               Old slope: 0.6451,
#               New intercept: 0.9393,
#               New slope: 0.6450
# Step: 401,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9393,
#               Old slope: 0.6450,
#               New intercept: 0.9394,
#               New slope: 0.6450
# Step: 402,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9394,
#               Old slope: 0.6450,
#               New intercept: 0.9395,
#               New slope: 0.6449
# Step: 403,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9395,
#               Old slope: 0.6449,
#               New intercept: 0.9396,
#               New slope: 0.6449
# Step: 404,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9396,
#               Old slope: 0.6449,
#               New intercept: 0.9398,
#               New slope: 0.6448
# Step: 405,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9398,
#               Old slope: 0.6448,
#               New intercept: 0.9399,
#               New slope: 0.6448
# Step: 406,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9399,
#               Old slope: 0.6448,
#               New intercept: 0.9400,
#               New slope: 0.6448
# Step: 407,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9400,
#               Old slope: 0.6448,
#               New intercept: 0.9401,
#               New slope: 0.6447
# Step: 408,
#               Step Size Intercept: -0.0001,
#               Step Size Slope: 0.0000,
#               Old intercept: 0.9401,
#               Old slope: 0.6447,
#               New intercept: 0.9402,
#               New slope: 0.6447
#
# --- Treinamento Concluído ---
# Intercept Final: 0.9402
# Slope Final: 0.6447
# Total de Iterações: 408

# %% [markdown]
# ### Animação da Convergência (Intercepto + Inclinação)
#
# O código a seguir gera a visualização final do algoritmo de **Gradient Descent**, otimizando o intercept e o slope.
#
# A função de atualização (`update`) reconstrói a equação da reta para cada iteração do histórico de treinamento:
#
# $$\hat{y} = \text{slope}_{\text{atual}} \cdot x + \text{intercept}_{\text{atual}}$$
#
# Diferente do exemplo anterior, tanto o slope quanto o intercept são alterados continuamente.

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(x_data, y_data, color='blue', zorder=5, label='Pontos Originais')
ax.set_title('Gradiente Descendente: Convergência do Intercept e Slope')
ax.set_xlabel('height')
ax.set_ylabel('weight')
ax.legend()
ax.grid(True)

x_line_anim = np.linspace(min(x_data) - 0.5, max(x_data) + 0.5, 100)

line, = ax.plot(x_line_anim,
                list_slopes[0] * x_line_anim + list_intercepts[0],
                color='red',
                label='Linha de Regressão')
iteration_text = ax.text(0.02, 0.95, '', transform=ax.transAxes, color='green')

def update(frame):
    current_intercept = list_intercepts[frame]
    current_slope = list_slopes[frame]
    y_line_anim = current_slope * x_line_anim + current_intercept
    line.set_ydata(y_line_anim)
    iteration_text.set_text(f'Iteração: {frame+1}\nIntercept: {current_intercept:.4f}\nSlope: {current_slope:.4f}')
    return line, iteration_text,

ani = FuncAnimation(fig, update, frames=len(list_intercepts), interval=20, blit=True)

plt.close(fig)
HTML(ani.to_jshtml())
# Out:
# Output hidden; open in https://colab.research.google.com to view.
