# %% [markdown]
# #Otimização com Gradiente Descendente
#
# Utilizaremos **Gradiente Descendente** para encontrar o `intercept` ideal em uma regressão linear simples
#
# $$
# y_i = \beta_0 + \beta_1 x_i + \epsilon_i
# $$
#
# **Onde:**
# * **$y_i$**: Variável dependente (resposta) para a observação $i$.
# * **$x_i$**: Variável independente (explicativa) para a observação $i$.
# * **$\beta_0$**: **Intercept** (onde a linha cruza o eixo $y$).
# * **$\beta_1$**: **slope** (coeficiente angular, ou quanto $y$ muda para cada unidade de $x$).
# * **$\epsilon_i$**: **Erro aleatório** (resíduo), variação em $y$ não explicada por $x$.
#
#
#
#  minimizando o erro entre previsões e dados reais (`x_data`, `y_data`).

# %% [markdown]
# ##Bibliotecas que usaremos

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %% [markdown]
# ## Definição das variaveis com os dados que usaremos:

# %%
intercept = 0
slope = 0.64
x_data = np.array([0.5, 2.3, 2.9])
y_data = np.array([1.4, 1.9, 3.2])
max_iterations = 1000
precision = 0.0001
learning_rate = 0.01
list_intercepts = []
list_sum_of_squared_residuals = []
list_sum_of_squared_derivatives = []

# %% [markdown]
# # Definição das funções
# Para facilitar a leitura, vamos associar as variáveis do código aos símbolos matemáticos:
# * **$y_i$**: `y_data`
# * **$x_i$**: `x_data`
# * **$b$**: `current_intercept`
# * **$m$**: `slope`

# %% [markdown]
# ### 1. Soma dos Quadrados dos Resíduos
# Correspondente à função `calculate_sum_of_squared_residuals`. Esta é a função de custo ($SSR$).
#
# $$
# SSR(b) = \sum_{i=1}^{n} (y_i - (b + m x_i))^2
# $$

# %%
def calculate_sum_of_squared_residuals(current_intercept):
    predictions = current_intercept + slope * x_data
    residuals = y_data - predictions
    return np.sum(residuals**2)

# %% [markdown]
# ### 2. Derivada da Função de Custo
# Correspondente à função `calculate_derivative`. Esta é a derivada parcial em relação ao intercepto ($b$).
#
# $$
# \frac{\partial SSR}{\partial b} = \sum_{i=1}^{n} -2 (y_i - (b + m x_i))
# $$

# %%
def calculate_derivative(current_intercept):
    predictions = current_intercept + slope * x_data
    residuals = y_data - predictions
    return np.sum(-2 * residuals)

# %% [markdown]
# ### Executando o Gradiente Descendente (Otimização do Intercepto)
#
# A cada iteração (passo do loop), o código realiza três tarefas principais, utilizando **todo o conjunto de dados**:
#
# 1.  **Calcula o Gradiente:** Determina a direção do erro com base em **todos os pontos** de dados simultaneamente.
# 2.  **Atualiza o Intercepto.**
# 3.  **Verifica a Precisão:** Se o passo de atualização do intercepto for pequeno demais (menor que a precisão definida), o loop encerra.
#
# O processo se repete até que o gradiente seja próximo de zero (convergência) ou o maximo de iterações for atingido.
#
# Também armazenamos o histórico dos valores do intercepto para a visualização da convergência do algoritmo em gráficos posteriores.

# %%
for i in range(max_iterations):
    list_intercepts.append(intercept)

    current_sum_of_squared_residuals = calculate_sum_of_squared_residuals(intercept)
    list_sum_of_squared_residuals.append(current_sum_of_squared_residuals)

    current_sum_of_squared_derivatives = calculate_derivative(intercept)
    list_sum_of_squared_derivatives.append(current_sum_of_squared_derivatives)

    print(f"""Step Size: {(learning_rate * current_sum_of_squared_derivatives):.4f},
              Old intercept: {intercept:.4f},
              New intercept: {(intercept - learning_rate * current_sum_of_squared_derivatives):.4f}""",
              flush=True)

    intercept = intercept - learning_rate * current_sum_of_squared_derivatives
    if np.abs(current_sum_of_squared_derivatives*learning_rate) < precision:
        break

print(f"Intercept Final: {intercept:.4f}")
print(f"SSR Final: {current_sum_of_squared_residuals:.4f}")
print(f"Total de Iterações: {len(list_intercepts)}")
# Out:
# Step Size: -0.0570,
#               Old intercept: 0.0000,
#               New intercept: 0.0570
# Step Size: -0.0536,
#               Old intercept: 0.0570,
#               New intercept: 0.1107
# Step Size: -0.0504,
#               Old intercept: 0.1107,
#               New intercept: 0.1611
# Step Size: -0.0474,
#               Old intercept: 0.1611,
#               New intercept: 0.2084
# Step Size: -0.0445,
#               Old intercept: 0.2084,
#               New intercept: 0.2530
# Step Size: -0.0419,
#               Old intercept: 0.2530,
#               New intercept: 0.2948
# Step Size: -0.0394,
#               Old intercept: 0.2948,
#               New intercept: 0.3342
# Step Size: -0.0370,
#               Old intercept: 0.3342,
#               New intercept: 0.3712
# Step Size: -0.0348,
#               Old intercept: 0.3712,
#               New intercept: 0.4059
# Step Size: -0.0327,
#               Old intercept: 0.4059,
#               New intercept: 0.4386
# Step Size: -0.0307,
#               Old intercept: 0.4386,
#               New intercept: 0.4693
# Step Size: -0.0289,
#               Old intercept: 0.4693,
#               New intercept: 0.4982
# Step Size: -0.0271,
#               Old intercept: 0.4982,
#               New intercept: 0.5254
# Step Size: -0.0255,
#               Old intercept: 0.5254,
#               New intercept: 0.5509
# Step Size: -0.0240,
#               Old intercept: 0.5509,
#               New intercept: 0.5749
# Step Size: -0.0225,
#               Old intercept: 0.5749,
#               New intercept: 0.5974
# Step Size: -0.0212,
#               Old intercept: 0.5974,
#               New intercept: 0.6186
# Step Size: -0.0199,
#               Old intercept: 0.6186,
#               New intercept: 0.6385
# Step Size: -0.0187,
#               Old intercept: 0.6385,
#               New intercept: 0.6573
# Step Size: -0.0176,
#               Old intercept: 0.6573,
#               New intercept: 0.6749
# Step Size: -0.0165,
#               Old intercept: 0.6749,
#               New intercept: 0.6914
# Step Size: -0.0156,
#               Old intercept: 0.6914,
#               New intercept: 0.7070
# Step Size: -0.0146,
#               Old intercept: 0.7070,
#               New intercept: 0.7216
# Step Size: -0.0137,
#               Old intercept: 0.7216,
#               New intercept: 0.7353
# Step Size: -0.0129,
#               Old intercept: 0.7353,
#               New intercept: 0.7483
# Step Size: -0.0121,
#               Old intercept: 0.7483,
#               New intercept: 0.7604
# Step Size: -0.0114,
#               Old intercept: 0.7604,
#               New intercept: 0.7718
# Step Size: -0.0107,
#               Old intercept: 0.7718,
#               New intercept: 0.7826
# Step Size: -0.0101,
#               Old intercept: 0.7826,
#               New intercept: 0.7926
# Step Size: -0.0095,
#               Old intercept: 0.7926,
#               New intercept: 0.8021
# Step Size: -0.0089,
#               Old intercept: 0.8021,
#               New intercept: 0.8110
# Step Size: -0.0084,
#               Old intercept: 0.8110,
#               New intercept: 0.8194
# Step Size: -0.0079,
#               Old intercept: 0.8194,
#               New intercept: 0.8273
# Step Size: -0.0074,
#               Old intercept: 0.8273,
#               New intercept: 0.8347
# Step Size: -0.0070,
#               Old intercept: 0.8347,
#               New intercept: 0.8416
# Step Size: -0.0065,
#               Old intercept: 0.8416,
#               New intercept: 0.8482
# Step Size: -0.0061,
#               Old intercept: 0.8482,
#               New intercept: 0.8543
# Step Size: -0.0058,
#               Old intercept: 0.8543,
#               New intercept: 0.8601
# Step Size: -0.0054,
#               Old intercept: 0.8601,
#               New intercept: 0.8656
# Step Size: -0.0051,
#               Old intercept: 0.8656,
#               New intercept: 0.8707
# Step Size: -0.0048,
#               Old intercept: 0.8707,
#               New intercept: 0.8755
# Step Size: -0.0045,
#               Old intercept: 0.8755,
#               New intercept: 0.8800
# Step Size: -0.0042,
#               Old intercept: 0.8800,
#               New intercept: 0.8842
# Step Size: -0.0040,
#               Old intercept: 0.8842,
#               New intercept: 0.8882
# Step Size: -0.0037,
#               Old intercept: 0.8882,
#               New intercept: 0.8919
# Step Size: -0.0035,
#               Old intercept: 0.8919,
#               New intercept: 0.8955
# Step Size: -0.0033,
#               Old intercept: 0.8955,
#               New intercept: 0.8988
# Step Size: -0.0031,
#               Old intercept: 0.8988,
#               New intercept: 0.9019
# Step Size: -0.0029,
#               Old intercept: 0.9019,
#               New intercept: 0.9048
# Step Size: -0.0028,
#               Old intercept: 0.9048,
#               New intercept: 0.9076
# Step Size: -0.0026,
#               Old intercept: 0.9076,
#               New intercept: 0.9102
# Step Size: -0.0024,
#               Old intercept: 0.9102,
#               New intercept: 0.9126
# Step Size: -0.0023,
#               Old intercept: 0.9126,
#               New intercept: 0.9149
# Step Size: -0.0021,
#               Old intercept: 0.9149,
#               New intercept: 0.9170
# Step Size: -0.0020,
#               Old intercept: 0.9170,
#               New intercept: 0.9190
# Step Size: -0.0019,
#               Old intercept: 0.9190,
#               New intercept: 0.9209
# Step Size: -0.0018,
#               Old intercept: 0.9209,
#               New intercept: 0.9227
# Step Size: -0.0017,
#               Old intercept: 0.9227,
#               New intercept: 0.9244
# Step Size: -0.0016,
#               Old intercept: 0.9244,
#               New intercept: 0.9260
# Step Size: -0.0015,
#               Old intercept: 0.9260,
#               New intercept: 0.9275
# Step Size: -0.0014,
#               Old intercept: 0.9275,
#               New intercept: 0.9288
# Step Size: -0.0013,
#               Old intercept: 0.9288,
#               New intercept: 0.9302
# Step Size: -0.0012,
#               Old intercept: 0.9302,
#               New intercept: 0.9314
# Step Size: -0.0012,
#               Old intercept: 0.9314,
#               New intercept: 0.9325
# Step Size: -0.0011,
#               Old intercept: 0.9325,
#               New intercept: 0.9336
# Step Size: -0.0010,
#               Old intercept: 0.9336,
#               New intercept: 0.9347
# Step Size: -0.0010,
#               Old intercept: 0.9347,
#               New intercept: 0.9356
# Step Size: -0.0009,
#               Old intercept: 0.9356,
#               New intercept: 0.9365
# Step Size: -0.0008,
#               Old intercept: 0.9365,
#               New intercept: 0.9374
# Step Size: -0.0008,
#               Old intercept: 0.9374,
#               New intercept: 0.9382
# Step Size: -0.0008,
#               Old intercept: 0.9382,
#               New intercept: 0.9389
# Step Size: -0.0007,
#               Old intercept: 0.9389,
#               New intercept: 0.9396
# Step Size: -0.0007,
#               Old intercept: 0.9396,
#               New intercept: 0.9403
# Step Size: -0.0006,
#               Old intercept: 0.9403,
#               New intercept: 0.9409
# Step Size: -0.0006,
#               Old intercept: 0.9409,
#               New intercept: 0.9415
# Step Size: -0.0006,
#               Old intercept: 0.9415,
#               New intercept: 0.9420
# Step Size: -0.0005,
#               Old intercept: 0.9420,
#               New intercept: 0.9426
# Step Size: -0.0005,
#               Old intercept: 0.9426,
#               New intercept: 0.9430
# Step Size: -0.0005,
#               Old intercept: 0.9430,
#               New intercept: 0.9435
# Step Size: -0.0004,
#               Old intercept: 0.9435,
#               New intercept: 0.9439
# Step Size: -0.0004,
#               Old intercept: 0.9439,
#               New intercept: 0.9443
# Step Size: -0.0004,
#               Old intercept: 0.9443,
#               New intercept: 0.9447
# Step Size: -0.0004,
#               Old intercept: 0.9447,
#               New intercept: 0.9451
# Step Size: -0.0003,
#               Old intercept: 0.9451,
#               New intercept: 0.9454
# Step Size: -0.0003,
#               Old intercept: 0.9454,
#               New intercept: 0.9457
# Step Size: -0.0003,
#               Old intercept: 0.9457,
#               New intercept: 0.9460
# Step Size: -0.0003,
#               Old intercept: 0.9460,
#               New intercept: 0.9463
# Step Size: -0.0003,
#               Old intercept: 0.9463,
#               New intercept: 0.9466
# Step Size: -0.0002,
#               Old intercept: 0.9466,
#               New intercept: 0.9468
# Step Size: -0.0002,
#               Old intercept: 0.9468,
#               New intercept: 0.9470
# Step Size: -0.0002,
#               Old intercept: 0.9470,
#               New intercept: 0.9473
# Step Size: -0.0002,
#               Old intercept: 0.9473,
#               New intercept: 0.9475
# Step Size: -0.0002,
#               Old intercept: 0.9475,
#               New intercept: 0.9477
# Step Size: -0.0002,
#               Old intercept: 0.9477,
#               New intercept: 0.9478
# Step Size: -0.0002,
#               Old intercept: 0.9478,
#               New intercept: 0.9480
# Step Size: -0.0002,
#               Old intercept: 0.9480,
#               New intercept: 0.9482
# Step Size: -0.0002,
#               Old intercept: 0.9482,
#               New intercept: 0.9483
# Step Size: -0.0001,
#               Old intercept: 0.9483,
#               New intercept: 0.9485
# Step Size: -0.0001,
#               Old intercept: 0.9485,
#               New intercept: 0.9486
# Step Size: -0.0001,
#               Old intercept: 0.9486,
#               New intercept: 0.9487
# Step Size: -0.0001,
#               Old intercept: 0.9487,
#               New intercept: 0.9488
# Step Size: -0.0001,
#               Old intercept: 0.9488,
#               New intercept: 0.9489
# Step Size: -0.0001,
#               Old intercept: 0.9489,
#               New intercept: 0.9490
# Step Size: -0.0001,
#               Old intercept: 0.9490,
#               New intercept: 0.9491
# Intercept Final: 0.9491
# SSR Final: 0.4446
# Total de Iterações: 104

# %% [markdown]
# ### Animação da Convergência (Intercept + slope)
#
# O código a seguir gera a visualização final do algoritmo de **Gradient Descent**, otimizando apenas o intercept.
#
# A função de atualização (`update`) reconstrói a equação da reta para cada iteração do histórico de treinamento:
#
# $$\hat{y} = \text{slope} \cdot x + \text{intercept}_{\text{atual}}$$

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(x_data, y_data, color='blue', zorder=5, label='Pontos Originais')
ax.set_title('Gradiente Descendente: Convergência do Intercept')
ax.set_xlabel('height')
ax.set_ylabel('Weight')
ax.legend()
ax.grid(True)

x_line_anim = np.linspace(min(x_data) - 0.5, max(x_data) + 0.5, 100)

line, = ax.plot(x_line_anim, slope * x_line_anim + list_intercepts[0], color='red', label='Linha de Regressão')
iteration_text = ax.text(0.02, 0.95, '', transform=ax.transAxes, color='green')

def update(frame):
    current_intercept = list_intercepts[frame]
    y_line_anim = slope * x_line_anim + current_intercept
    line.set_ydata(y_line_anim)
    iteration_text.set_text(f'Iteração: {frame+1}\nIntercept: {current_intercept:.4f}')
    return line, iteration_text,

ani = FuncAnimation(fig, update, frames=len(list_intercepts), interval=80, blit=True)

plt.close(fig)
HTML(ani.to_jshtml())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Visualizando a Função de Custo e a Tangente
# * **Curva Roxa:** Representa o erro total (SSR) para cada valor possível de intercepto.
# * **Ponto Vermelho:** valor atual do nosso intercepto.
# * **Linha Laranja (Tangente):** representação visual da **derivada** no ponto.
#
# Equação da reta tangente:
#
# $$
#  y = m \cdot (x - x_0) + y_0
# $$
#
# **Onde:**
# * **$y$**: O valor da linha tangente que será desenhado.
# * **$x_0$**: O **Intercept Atual** (onde o ponto vermelho está no eixo X).
# * **$y_0$**: O erro atual (**SSR**) (altura do ponto vermelho).
# * **$m$**: A inclinação da reta, que é exatamente o **Gradiente** calculado.
# :

# %%
intercept_values_plot = np.linspace(0, 2, 200)
sum_of_squared_values_plot = [calculate_sum_of_squared_residuals(i) for i in intercept_values_plot]

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(intercept_values_plot, sum_of_squared_values_plot, color='purple', linestyle='-', label='Função de Perda (SSR)')
ax.set_title('Convergência na Função de Perda com Tangente')
ax.set_xlabel('Intercept')
ax.set_ylabel('Soma dos Quadrados dos Resíduos (SSR)')
ax.legend()
ax.grid(True)

point, = ax.plot([], [], 'o', color='red', markersize=8, label='Intercept Atual')
tangent_line, = ax.plot([], [], '--', color='orange', label='Linha Tangente')
iteration_text = ax.text(0.02, 0.95, '', transform=ax.transAxes, color='green', fontsize=12)

def update(frame):
    if frame >= len(list_intercepts) or frame >= len(list_sum_of_squared_residuals) or frame >= len(list_sum_of_squared_derivatives):
        return point, tangent_line, iteration_text

    current_intercept = list_intercepts[frame]
    current_ssr = list_sum_of_squared_residuals[frame]
    current_gradient = list_sum_of_squared_derivatives[frame]

    point.set_data([current_intercept], [current_ssr])

    tangent_x = np.linspace(current_intercept - 0.2, current_intercept + 0.2, 2)
    tangent_y = current_gradient * (tangent_x - current_intercept) + current_ssr

    tangent_line.set_data(tangent_x, tangent_y)

    iteration_text.set_text(f'Iteração: {frame+1}\nIntercept: {current_intercept:.4f}\nSSR: {current_ssr:.4f}')

    return point, tangent_line, iteration_text

ani = FuncAnimation(fig, update, frames=len(list_intercepts), interval=80, blit=True)

plt.close(fig)
HTML(ani.to_jshtml())
# Out:
# Output hidden; open in https://colab.research.google.com to view.
